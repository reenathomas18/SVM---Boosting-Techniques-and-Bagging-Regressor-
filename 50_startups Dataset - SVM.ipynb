# %% [markdown]
# ## Assignment Task
# 1. SVM

# %%
#Importing libraries
import numpy as np
import pandas as pd

# %%
#Loading dataset
df = pd.read_csv('50_Startups.csv')
df.head()
# Out:
#    R&D Spend  Administration  Marketing Spend       State     Profit
# 0  165349.20       136897.80        471784.10    New York  192261.83
# 1  162597.70       151377.59        443898.53  California  191792.06
# 2  153441.51       101145.55        407934.54     Florida  191050.39
# 3  144372.41       118671.85        383199.62    New York  182901.99
# 4  142107.34        91391.77        366168.42     Florida  166187.94

# %%
df.info()  # - Indicates that there are no missing values
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 50 entries, 0 to 49
# Data columns (total 5 columns):
# R&D Spend          50 non-null float64
# Administration     50 non-null float64
# Marketing Spend    50 non-null float64
# State              50 non-null object
# Profit             50 non-null float64
# dtypes: float64(4), object(1)
# memory usage: 2.1+ KB

# %%
df.describe() #Indicates that there are no outliers
# Out:
#            R&D Spend  Administration  Marketing Spend         Profit
# count      50.000000       50.000000        50.000000      50.000000
# mean    73721.615600   121344.639600    211025.097800  112012.639200
# std     45902.256482    28017.802755    122290.310726   40306.180338
# min         0.000000    51283.140000         0.000000   14681.400000
# 25%     39936.370000   103730.875000    129300.132500   90138.902500
# 50%     73051.080000   122699.795000    212716.240000  107978.190000
# 75%    101602.800000   144842.180000    299469.085000  139765.977500
# max    165349.200000   182645.560000    471784.100000  192261.830000

# %%
import matplotlib.pyplot as plt
box_df = df.iloc[:,[0,1,2]]
box_df.plot(kind='box', figsize= (7,5),subplots=True, layout=(1,3))
plt.show()

# %%
#Step 1 : Bagging Classifier using Shuffling Technique

# %%
#Entire training dataset will be considered for training each model however the data will be shuffled for each model

# %%
#Check and Handle categorical data
#State is the only categorical data that needs to be handled. Rest are numerica data
df.State.unique()
dfU = pd.concat([pd.get_dummies(df.State), df.iloc[:,[0,1,2,4]]] , axis = 1)
#pd.get_dummies(df.Pincode)
dfU
# Out:
#     California  Florida  New York  R&D Spend  Administration  Marketing Spend  \
# 0            0        0         1  165349.20       136897.80        471784.10
# 1            1        0         0  162597.70       151377.59        443898.53
# 2            0        1         0  153441.51       101145.55        407934.54
# 3            0        0         1  144372.41       118671.85        383199.62
# 4            0        1         0  142107.34        91391.77        366168.42
# 5            0        0         1  131876.90        99814.71        362861.36
# 6            1        0         0  134615.46       147198.87        127716.82
# 7            0        1         0  130298.13       145530.06        323876.68
# 8            0        0         1  120542.52       148718.95        311613.29
# 9            1        0         0  123334.88       108679.17        304981.62
# 10           0        1         0  101913.08       110594.11        229160.95
# ...

# %%
dfU
# Out:
#     California  Florida  New York  R&D Spend  Administration  Marketing Spend  \
# 0            0        0         1  165349.20       136897.80        471784.10
# 1            1        0         0  162597.70       151377.59        443898.53
# 2            0        1         0  153441.51       101145.55        407934.54
# 3            0        0         1  144372.41       118671.85        383199.62
# 4            0        1         0  142107.34        91391.77        366168.42
# 5            0        0         1  131876.90        99814.71        362861.36
# 6            1        0         0  134615.46       147198.87        127716.82
# 7            0        1         0  130298.13       145530.06        323876.68
# 8            0        0         1  120542.52       148718.95        311613.29
# 9            1        0         0  123334.88       108679.17        304981.62
# 10           0        1         0  101913.08       110594.11        229160.95
# ...

# %%
features = dfU.iloc[:,:-1].values
label=dfU.iloc[:,[-1]].values

# %%
#Train Test Split
from sklearn.model_selection import train_test_split
X_train,X_test,y_train,y_test = train_test_split(features,
                                                label,
                                                test_size=0.2,
                                                random_state=23)

# %%
# Tweaking to show you decision regions

# %%
import warnings
warnings.filterwarnings('ignore')

# %%
#KNN with Bagging Classifier

from sklearn.ensemble import BaggingRegressor
from sklearn.neighbors import KNeighborsRegressor

algorithm = KNeighborsRegressor()

model = BaggingRegressor(n_estimators=11,
                         base_estimator=algorithm)

model.fit(X_train,y_train)
# Out:
# BaggingRegressor(base_estimator=KNeighborsRegressor(algorithm='auto',
#                                                     leaf_size=30,
#                                                     metric='minkowski',
#                                                     metric_params=None,
#                                                     n_jobs=None, n_neighbors=5,
#                                                     p=2, weights='uniform'),
#                  bootstrap=True, bootstrap_features=False, max_features=1.0,
#                  max_samples=1.0, n_estimators=11, n_jobs=None, oob_score=False,
#                  random_state=None, verbose=0, warm_start=False)

# %%
print(model.score(X_train,y_train))
print(model.score(X_test,y_test))
# Out:
# 0.8438634509320438
# 0.7589538779379169

# %%
#Commenting out the below code so that execution happens faster
'''
def determine_RS_and_ES(features,label):
    max_ts = 0
    max_es = 0
    max_rs = 0
    model = None
    for i in range(1,51):
        X_train,X_test,y_train,y_test = train_test_split(features,
                                                    label,
                                                    test_size=0.2,
                                                    random_state=i)
        for j in range(1,51):
            algorithm = KNeighborsRegressor()
            model = BaggingRegressor(n_estimators=j,
                             base_estimator=algorithm)
            model.fit(X_train,y_train)

            train_s=model.score(X_train,y_train)
            test_s=model.score(X_test,y_test)

            if test_s > train_s:
                #print("Test Score {} Train Score {} RS {}".format(test_s,train_s,i))
                if test_s > max_ts:
                    max_ts = test_s
                    max_rs = i
                    max_es = j
                    model = model
        #print ("test score inside i loop %r " % max_ts)
    return max_ts, max_rs, max_es, X_train,X_test,y_train,y_test , model

max_ts, max_rs , max_es, X_train,X_test,y_train,y_test, model   = determine_RS_and_ES(features,label)

print ("Random state %r Estimators %r  corresponding to max test score %r   " %(max_rs,max_es, max_ts))

'''
# Out:
# '\ndef determine_RS_and_ES(features,label):\n    max_ts = 0\n    max_es = 0\n    max_rs = 0\n    model = None\n    for i in range(1,51):\n        X_train,X_test,y_train,y_test = train_test_split(features,\n                                                    label,\n                                                    test_size=0.2,\n                                                    random_state=i)\n        for j in range(1,51):\n            algorithm = KNeighborsRegressor()\n            model = BaggingRegressor(n_estimators=j,\n                             base_estimator=algorithm)\n            model.fit(X_train,y_train)\n\n            train_s=model.score(X_train,y_train)\n            test_s=model.score(X_test,y_test)\n\n            if test_s > train_s:\n                #print("Test Score {} Train Score {} RS {}".format(test_s,train_s,i))\n                if test_s > max_ts:\n                    max_ts = test_s\n                    max_rs = i\n                    max_es = j\n       
# ...

# %%
#Random state 33 Estimators 12 corresponding to max test score 0.9581
features

# %%
#Train Test Split
from sklearn.model_selection import train_test_split
X_train,X_test,y_train,y_test = train_test_split(features,
                                                label,
                                                test_size=0.2,
                                                random_state=33)

# %%
#KNN with Bagging Classifier

from sklearn.ensemble import BaggingRegressor
from sklearn.neighbors import KNeighborsRegressor

algorithm = KNeighborsRegressor()

model = BaggingRegressor(n_estimators=12,
                         base_estimator=algorithm)

model.fit(X_train,y_train)
# Out:
# BaggingRegressor(base_estimator=KNeighborsRegressor(algorithm='auto',
#                                                     leaf_size=30,
#                                                     metric='minkowski',
#                                                     metric_params=None,
#                                                     n_jobs=None, n_neighbors=5,
#                                                     p=2, weights='uniform'),
#                  bootstrap=True, bootstrap_features=False, max_features=1.0,
#                  max_samples=1.0, n_estimators=12, n_jobs=None, oob_score=False,
#                  random_state=None, verbose=0, warm_start=False)

# %%
print(model.score(X_train,y_train))
print(model.score(X_test,y_test))
# Out:
# 0.797666532866263
# 0.9148835576292098

# %%
#Use the above code with for loops to determine estimators and best RS

# %% [markdown]
# ## SVM

# %%
#1. Assume only two features (So that I can show you decision region in XY plane)

finalFeatures = X_train[:,3:5]
#2. Convert the labels into numeric labels(Discrete labels)(1-setosa,2-versicolor,3-virginica)
finalLabels = y_train.values.ravel()
finalLabels

# %%
finalFeatures

# %% [markdown]
# ### SVM Regressor - Linear

# %%
from sklearn.svm import SVR
model3 = SVR('linear') #linear regressor

# %%
model3.fit(finalFeatures,finalLabels)

# %%
model3.score(finalFeatures, finalLabels)

# %%
model3.score(X_test, y_test)

# %% [markdown]
# ### SVM Regressor - RBF

# %%
model4 = SVR(kernel="rbf")

# %%
model4.fit(finalFeatures,finalLabels)

# %%
model4.score(finalFeatures, finalLabels)

# %%
model4.score(X_test, y_test)

# %% [markdown]
# ### SVM Regressor - Poly

# %%
model5 = SVR(kernel="poly")
model5.fit(finalFeatures,finalLabels)

# %%
model5.score(finalFeatures, finalLabels)

# %%
model5.score(X_test, y_test)

# %% [markdown]
# ### SVM Regressor - Sigmoid

# %%
model6 = SVC(kernel="sigmoid")
model6.fit(finalFeatures,finalLabels)

# %%
model6.score(finalFeatures, finalLabels)

# %%
model6.score(X_test, y_test)
